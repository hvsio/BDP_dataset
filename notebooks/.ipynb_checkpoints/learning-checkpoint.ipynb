# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, ElasticNetCV, LassoCV, SGDRegressor
import statsmodels.api as sm
from scipy import stats
from IPython.display import display_html
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import cross_val_score, RepeatedKFold, ShuffleSplit, GridSearchCV
from sklearn import metrics
from pactools.grid_search import GridSearchCVProgressBar

# %%
df = pd.read_csv('../cleaned_data/clean_v5_fillednans.csv', delimiter=',')

# %%
corr = df.corr(method='spearman')
#_, ax = plt.subplots(figsize=(20,10)) 
#sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu_r', annot=True, linewidth=0.5, ax=ax)

# %%
defaults = [
    'GDP per capita',
    'Social support',
    'Healthy life expectancy at birth',
    'Freedom to make life choices',
    'Generosity',
    'Perceptions of corruption',
    'Positive affect',
    'Negative affect'
]

discovered_params = [
    'Trust in government',
    'Health spending',
    'Internet access',
    'Home access to computers',
    'Average wage',
    'Poverty rate',
]

additional_params = [
    'Self-employment rate',
    'Households overcrowding',
]

Y = df[['Happiness index']].values
Y_bin = df[['Happy country']].values
X_default = df[[*defaults]].values
X_basis = df[[*defaults, *discovered_params]].values
X_extended = df[[*defaults, *discovered_params, *additional_params]].values
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)
X_train, X_test, Y_train, Y_test = train_test_split(X_extended, Y, test_size=0.2, random_state=41)
X_train_bin, X_test_bin, Y_train_bin, Y_test_bin = train_test_split(X_extended, Y_bin, test_size=0.2, random_state=41)

# %%
corr = df[[*defaults, *discovered_params, *additional_params]].corr(method='spearman')
_, ax = plt.subplots(figsize=(20,10)) 
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu_r', annot=True, linewidth=0.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
def train_linear(X):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=41)
    pipeline_linear = make_pipeline(StandardScaler(), LinearRegression())
    pipeline_linear.fit(X_train, Y_train)
    Y_pred_test = pipeline_linear.predict(X_test)
    print_test_results(pipeline_linear, X_test, Y_test)
    return pipeline_linear
    
def train_classifier(X, linear=True):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y_bin, test_size=0.2, random_state=41)
    pipline_logistic = make_pipeline(StandardScaler(), LogisticRegression()) #LogisticRegression(C=1, penalty='l1', solver='liblinear')
    pipline_logistic.fit(X_train, Y_train.ravel())
    print_test_results(pipline_logistic, X_test, Y_test, linear)
    return pipline_logistic

def print_test_results(model, xtest, ytest, linear=True):
    test_score = model.score(xtest, ytest)
    ypred = model.predict(xtest)
    if linear:
        metric = "Adjusted R2 // RMSE"
        adj_r2 = round(1 - (1-test_score)*((len(xtest)-1)/(len(xtest)-xtest.shape[1]-1)), 5)
        rmse = metrics.mean_squared_error(ytest, ypred, squared=False)
        test_score = f"{adj_r2} // {rmse}"
    else:
        metric = "Accuracy // Recall // Precision // F1"
        recall = round(metrics.recall_score(ytest, ypred), 5)
        precision = round(metrics.precision_score(ytest, ypred), 5)
        f1 = round(metrics.f1_score(ytest, ypred), 5)
        test_score = f"{test_score} // {recall} // {precision} // {f1}"
    print(f'{metric} on testing set: {test_score}')

# %%
print("LinearR with default parameters:")
model_def_lin = train_linear(X_default)
print("\nLogisticR with default parameters:")
model_def_log = train_classifier(X_default, False)

print("-----\nLinearR with discovered parameters:")
model_disc_lin = train_linear(X_basis)
print("\nLogisticR with discovered parameters:")
model_disc_log = train_classifier(X_basis, False)

print("------\nLinearR with discovered + additional parameters:")
model_ext_lin = train_linear(X_extended)
print("\nLogisticR with discovered + additional parameters:")
model_ext_log = train_classifier(X_extended, False)
# Out:
# LinearR with default parameters:
# Adjusted R2 // RMSE on testing set: 0.70086 // 0.44882316328181737
#
# LogisticR with default parameters:
# Accuracy // Recall // Precision // F1 on testing set: 0.6126126126126126 // 0.73973 // 0.69231 // 0.71523
# -----
# LinearR with discovered parameters:
# Adjusted R2 // RMSE on testing set: 0.70015 // 0.4359430314137725
#
# LogisticR with discovered parameters:
# Accuracy // Recall // Precision // F1 on testing set: 0.6396396396396397 // 0.75342 // 0.71429 // 0.73333
# ------
# LinearR with discovered + additional parameters:
# Adjusted R2 // RMSE on testing set: 0.70333 // 0.4290843170114284
#
# LogisticR with discovered + additional parameters:
# Accuracy // Recall // Precision // F1 on testing set: 0.6576576576576577 // 0.73973 // 0.73973 // 0.73973

# %%
Y_hat = model_ext_log.predict_proba(X_extended)[::,1]
fpr, tpr, _ = metrics.roc_curve(Y_bin,  Y_hat)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# calculate area under the curve (AUC)
auc = metrics.roc_auc_score(Y_bin, Y_hat)
print(auc)
# Out:
# 0.7547650860305948

# %%
# CLASSIFICATION k-cross validation
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

parameters = {
    'logisticregression__penalty' : ['l1', 'l2'], 
    'logisticregression__C'       : np.logspace(-3, 10, 10),
    'logisticregression__solver'  : ['newton-cg', 'lbfgs', 'liblinear'],
}
clf = GridSearchCV(model_ext_log,param_grid = parameters, scoring='f1', cv=cv)
clf.fit(X_train_bin, Y_train_bin)
# Out:
# GridSearchCV(cv=RepeatedKFold(n_repeats=3, n_splits=5, random_state=1),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression())]),
#              param_grid={'logisticregression__C': array([1.00000000e-03, 2.78255940e-02, 7.74263683e-01, 2.15443469e+01,
#        5.99484250e+02, 1.66810054e+04, 4.64158883e+05, 1.29154967e+07,
#        3.59381366e+08, 1.00000000e+10]),
#                          'logisticregression__penalty': ['l1', 'l2'],
#                          'logisticregression__solver': ['newton-cg', 'lbfgs',
#                                                         'liblinear']},
#              scoring='f1')

# %%
print("Tuned Hyperparameters :", clf.best_params_)
print_test_results(clf, X_test_bin, Y_test_bin, False)
# Out:
# Tuned Hyperparameters : {'logisticregression__C': 0.027825594022071243, 'logisticregression__penalty': 'l2', 'logisticregression__solver': 'newton-cg'}
# Accuracy // Recall // Precision // F1 on testing set: 0.7468354430379747 // 0.80822 // 0.69412 // 0.74684

# %%
# LINEAR k-cross validation
k_model = GridSearchCV(estimator = model_ext_lin, 
                        param_grid = {
                            'linearregression__fit_intercept': [True, False],
                            'linearregression__positive': [True, False]
                        }, 
                        scoring= 'r2', 
                        cv = cv)
k_model.fit(X_train, Y_train)
print_test_results(k_model, X_test, Y_test)
# Out:
# Adjusted R2 on testing set: 0.70333

# %%
plt.figure(figsize=(8,6)) 
ax = sns.residplot(pred, residuals)
ax.set_title('Residuals vs Predicted Values')
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Residuals')
plt.show()

# %%
# PCA to reduce the number of independent variables/reduce dimensionality
pca = PCA(n_components='mle')
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
explained_var = pca.explained_variance_ratio_
print(explained_var)
# Out:
# [9.99994556e-01 3.49230796e-06 1.00157738e-06 3.96981394e-07
#  2.79855294e-07 1.49344199e-07 9.27917788e-08 3.04775693e-08
#  4.60410647e-10 1.63262494e-10 7.47488035e-11 5.59631825e-11
#  1.89626122e-11]

# %%
# RIDGE k-cross validation - Rather failed
ridge = make_pipeline(StandardScaler(), Ridge())
ridge.fit(X_train, Y_train)
print_test_results(ridge, X_test, Y_test)

param = {
    'ridge__fit_intercept':[True,False],
    'ridge__solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
    'ridge__alpha': [0.0015, 0.001, 0.002, 0.003]
    
}
k_model = GridSearchCV(estimator = ridge, 
                        param_grid = param,
                        scoring= 'r2', 
                        cv = cv,
                      )

k_model.fit(X_train, Y_train)
print_test_results(k_model, X_test, Y_test)
# Out:
# Adjusted R2 on testing set: 0.66399
# Adjusted R2 on testing set: 0.66345
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.ensemble import RandomForestRegressor

basic_forest = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('estimator', RandomForestRegressor())
])
basic_forest.fit(X_train, Y_train)
print_test_results(basic_forest, X_test, Y_test)

forest_model = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('estimator', RandomForestRegressor())
])
forest_model.fit(X_train, Y_train)
y_hat = forest_model.predict(X_test)
sns.distplot(Y_test-y_hat)
print_test_results(forest_model, X_test, Y_test)
print(forest_model.get_params().keys())
# Out:
# Adjusted R2 // RMSE on testing set: 0.84425 // 0.3158217691100257
# Adjusted R2 // RMSE on testing set: 0.88712 // 0.2688657413463824
# dict_keys(['memory', 'steps', 'verbose', 'scaler', 'pca', 'estimator', 'scaler__copy', 'scaler__with_mean', 'scaler__with_std', 'pca__copy', 'pca__iterated_power', 'pca__n_components', 'pca__random_state', 'pca__svd_solver', 'pca__tol', 'pca__whiten', 'estimator__bootstrap', 'estimator__ccp_alpha', 'estimator__criterion', 'estimator__max_depth', 'estimator__max_features', 'estimator__max_leaf_nodes', 'estimator__max_samples', 'estimator__min_impurity_decrease', 'estimator__min_samples_leaf', 'estimator__min_samples_split', 'estimator__min_weight_fraction_leaf', 'estimator__n_estimators', 'estimator__n_jobs', 'estimator__oob_score', 'estimator__random_state', 'estimator__verbose', 'estimator__warm_start'])

# %%
import warnings 
warnings.filterwarnings("ignore")
forest_CV = GridSearchCV(
        estimator=forest_model,
        param_grid={
            'estimator__max_depth': range(5,),
            'estimator__bootstrap': [True, False],
            #'estimator__max_features': ['auto', 'sqrt', 'log2'],
            #'estimator__min_samples_leaf': [1, 2],
            #'estimator__min_samples_split': [2, 3],
            #'estimator__n_estimators': [1000]
        },
        cv=cv,
        scoring='r2',
        verbose=False
        #n_jobs=-1
        )
forest_CV.fit(X_train, Y_train)
#rfr = RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"],                               random_state=False, verbose=False)
# Perform K-Fold CV
#scores = cross_val_score(rfr, X_train, Y_train, cv=10, scoring='neg_mean_absolute_error')

# %%
print(forest_CV.best_params_)
print(forest_CV.best_score_)
print_test_results(forest_CV, X_test, Y_test)
# Out:
# {'estimator__bootstrap': True, 'estimator__max_depth': 4, 'estimator__max_features': 'auto'}
# 0.7014183544139512
# Adjusted R2 // RMSE on testing set: 0.79199 // 0.3649779866399478

# %%
y_hat = forest_CV.predict(X_test)
sns.distplot(Y_test-y_hat)
print("R-squared: ", r2_score(Y_test, y_hat))

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_bin, Y_train_bin)
print_test_results(gnb, X_test_bin, Y_test_bin)
# Out:
# Adjusted R2 // RMSE on testing set: 0.51505 // 0.643750273331526

# %%
nb_classifier = GaussianNB()

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gs_NB = GridSearchCV(estimator=nb_classifier, 
                 param_grid=params_NB, 
                 cv=cv,   # use any cross validation technique 
                 verbose=1, 
                 scoring='accuracy') 
gs_NB.fit(X_train_bin, Y_train_bin)

gs_NB.best_params_
print_test_results(gs_NB, X_test_bin, Y_test_bin)
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# Adjusted R2 // RMSE on testing set: 0.51505 // 0.643750273331526
