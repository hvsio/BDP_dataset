# %%
import pandas as pd
import numpy as np

# %%
def clean_data(merged_df, path, renamed_column, quad=False):
    df = pd.read_csv(f'../inputs_extended/{path}.csv', delimiter=',')[['LOCATION', 'TIME', 'Value']]
    if quad: 
        df['TIME'] = df['TIME'].str.slice(0,4).astype('int64')
        
    df.drop_duplicates(subset=['LOCATION', 'TIME'], keep='first', inplace=True)
    df_final = pd.merge(merged_df, df, on=['LOCATION', 'TIME'], how="outer")
    df_final.rename(columns={'Value': renamed_column}, inplace=True)
    df_final.reset_index(drop=True, inplace=True)
    return df_final

# %%
#main dataframe
main_df = pd.read_excel('../inputs_extended/happiness.xls')
main_df.drop(labels=[
    'Healthy life expectancy at birth',
    'Generosity',
    'Positive affect',
    'Negative affect',
    ], axis=1, inplace=True)
main_df.rename(columns={'year': 'TIME'}, inplace=True)

# %%
# merge with country codes
df = pd.read_csv('../inputs_extended/codes.csv', delimiter=',')[['English short name lower case', 'Alpha-3 code']]
df.rename(columns={'Alpha-3 code': 'LOCATION', 'English short name lower case': 'Country name'}, inplace=True)
df_v1 = pd.merge(main_df, df, on=['Country name'], how="outer").dropna(thresh=4)
df_v1 = df_v1.dropna().reset_index(drop=True)

# %%
# inflation
df_v2 = clean_data(df_v1, 'inflation', 'Inflation rate', True)
df_v2
# Out:
#      Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008.0     3.723590            7.370100        0.450662
# 1     Afghanistan  2009.0     4.401778            7.539972        0.552308
# 2     Afghanistan  2010.0     4.758381            7.646709        0.539075
# 3     Afghanistan  2011.0     3.831719            7.619532        0.521104
# 4     Afghanistan  2012.0     3.782938            7.705479        0.520637
# ...           ...     ...          ...                 ...             ...
# 3937          NaN  2021.0          NaN                 NaN             NaN
# 3938          NaN  2001.0          NaN                 NaN             NaN
# 3939          NaN  2000.0          NaN                 NaN             NaN
# 3940          NaN  2022.0          NaN                 NaN             NaN
# 3941          NaN  1999.0          NaN                 NaN             NaN
#
#       Freedom to make life choices  Perceptions of corruption   LOCATION  \
# 0                         0.718114                   0.881686        AFG
# 1                         0.678896                   0.850035        AFG
# 2                         0.600127                   0.706766        AFG
# 3                         0.495901                   0.731109        AFG
# 4                         0.530935                   0.775620        AFG
# ...                            ...                        ...        ...
# 3937                           NaN                        NaN  EU27_2020
# 3938                           NaN                        NaN  EU27_2020
# 3939                           NaN                        NaN  EU27_2020
# 3940                           NaN                        NaN  EU27_2020
# 3941                           NaN                        NaN  EU27_2020
#
#       Inflation rate
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 3937           12.60
# 3938            6.80
# 3939           69.60
# 3940           27.00
# 3941           67.56
#
# [3942 rows x 9 columns]

# %%
# adult education
df_v3 = clean_data(df_v2, 'adult-education', 'Adult education')
df_v3
# Out:
#      Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008.0     3.723590            7.370100        0.450662
# 1     Afghanistan  2009.0     4.401778            7.539972        0.552308
# 2     Afghanistan  2010.0     4.758381            7.646709        0.539075
# 3     Afghanistan  2011.0     3.831719            7.619532        0.521104
# 4     Afghanistan  2012.0     3.782938            7.705479        0.520637
# ...           ...     ...          ...                 ...             ...
# 3989          NaN  2010.0          NaN                 NaN             NaN
# 3990          NaN  2011.0          NaN                 NaN             NaN
# 3991          NaN  2012.0          NaN                 NaN             NaN
# 3992          NaN  2018.0          NaN                 NaN             NaN
# 3993          NaN  2019.0          NaN                 NaN             NaN
#
#       Freedom to make life choices  Perceptions of corruption LOCATION  \
# 0                         0.718114                   0.881686      AFG
# 1                         0.678896                   0.850035      AFG
# 2                         0.600127                   0.706766      AFG
# 3                         0.495901                   0.731109      AFG
# 4                         0.530935                   0.775620      AFG
# ...                            ...                        ...      ...
# 3989                           NaN                        NaN      G20
# 3990                           NaN                        NaN      G20
# 3991                           NaN                        NaN      G20
# 3992                           NaN                        NaN      G20
# 3993                           NaN                        NaN      G20
#
#       Inflation rate  Adult education
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# ...              ...              ...
# 3989             NaN        37.730685
# 3990             NaN        38.054268
# 3991             NaN        38.172514
# 3992             NaN        34.080354
# 3993             NaN        35.249791
#
# [3994 rows x 10 columns]

# %%
# housing prices
df_v4 = clean_data(df_v3, 'housing-prices', 'Housing prices', True)
# Out:
#      Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008.0     3.723590            7.370100        0.450662
# 1     Afghanistan  2009.0     4.401778            7.539972        0.552308
# 2     Afghanistan  2010.0     4.758381            7.646709        0.539075
# 3     Afghanistan  2011.0     3.831719            7.619532        0.521104
# 4     Afghanistan  2012.0     3.782938            7.705479        0.520637
# ...           ...     ...          ...                 ...             ...
# 4092          NaN  2008.0          NaN                 NaN             NaN
# 4093          NaN  2009.0          NaN                 NaN             NaN
# 4094          NaN  2020.0          NaN                 NaN             NaN
# 4095          NaN  2021.0          NaN                 NaN             NaN
# 4096          NaN  2021.0          NaN                 NaN             NaN
#
#       Freedom to make life choices  Perceptions of corruption LOCATION  \
# 0                         0.718114                   0.881686      AFG
# 1                         0.678896                   0.850035      AFG
# 2                         0.600127                   0.706766      AFG
# 3                         0.495901                   0.731109      AFG
# 4                         0.530935                   0.775620      AFG
# ...                            ...                        ...      ...
# 4092                           NaN                        NaN      BGR
# 4093                           NaN                        NaN      BGR
# 4094                           NaN                        NaN      ROU
# 4095                           NaN                        NaN      BGR
# 4096                           NaN                        NaN      ROU
#
#       Inflation rate  Adult education  Housing prices
# 0                NaN              NaN             NaN
# 1                NaN              NaN             NaN
# 2                NaN              NaN             NaN
# 3                NaN              NaN             NaN
# 4                NaN              NaN             NaN
# ...              ...              ...             ...
# 4092             NaN              NaN      147.972500
# 4093             NaN              NaN      117.785000
# 4094             NaN              NaN      128.435000
# 4095             NaN              NaN      144.852440
# 4096             NaN              NaN      130.839694
#
# [4097 rows x 11 columns]

# %%
# adult education
df_v5 = clean_data(df_v4, 'trust-in-gov', 'Trust in government')
df_v5
# Out:
#      Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008.0     3.723590            7.370100        0.450662
# 1     Afghanistan  2009.0     4.401778            7.539972        0.552308
# 2     Afghanistan  2010.0     4.758381            7.646709        0.539075
# 3     Afghanistan  2011.0     3.831719            7.619532        0.521104
# 4     Afghanistan  2012.0     3.782938            7.705479        0.520637
# ...           ...     ...          ...                 ...             ...
# 4092          NaN  2008.0          NaN                 NaN             NaN
# 4093          NaN  2009.0          NaN                 NaN             NaN
# 4094          NaN  2020.0          NaN                 NaN             NaN
# 4095          NaN  2021.0          NaN                 NaN             NaN
# 4096          NaN  2021.0          NaN                 NaN             NaN
#
#       Freedom to make life choices  Perceptions of corruption LOCATION  \
# 0                         0.718114                   0.881686      AFG
# 1                         0.678896                   0.850035      AFG
# 2                         0.600127                   0.706766      AFG
# 3                         0.495901                   0.731109      AFG
# 4                         0.530935                   0.775620      AFG
# ...                            ...                        ...      ...
# 4092                           NaN                        NaN      BGR
# 4093                           NaN                        NaN      BGR
# 4094                           NaN                        NaN      ROU
# 4095                           NaN                        NaN      BGR
# 4096                           NaN                        NaN      ROU
#
#       Inflation rate  Adult education  Housing prices  Trust in government
# 0                NaN              NaN             NaN                  NaN
# 1                NaN              NaN             NaN                  NaN
# 2                NaN              NaN             NaN                  NaN
# 3                NaN              NaN             NaN                  NaN
# 4                NaN              NaN             NaN                  NaN
# ...              ...              ...             ...                  ...
# 4092             NaN              NaN      147.972500                  NaN
# 4093             NaN              NaN      117.785000                  NaN
# 4094             NaN              NaN      128.435000                  NaN
# 4095             NaN              NaN      144.852440                  NaN
# 4096             NaN              NaN      130.839694                  NaN
#
# [4097 rows x 12 columns]

# %%
# Dataframe check
print(f"""
{df_v5['Inflation rate'].isna().sum()}
{df_v5['Adult education'].isna().sum()}
{df_v5['Housing prices'].isna().sum()}
{df_v5['Trust in government'].isna().sum()}
""")
df_v5 = df_v5.dropna(thresh=10).reset_index(drop=True)
print(f"""
{df_v5['Inflation rate'].isna().sum()}
{df_v5['Adult education'].isna().sum()}
{df_v5['Housing prices'].isna().sum()}
{df_v5['Trust in government'].isna().sum()}
""")
df_v5
# Out:
# 1254
# 3067
# 1996
# 3660
#
#
# 14
# 44
# 3
# 156
#       Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0        Argentina  2017.0     6.039330           10.067430        0.906699
# 1        Argentina  2018.0     5.792797           10.032141        0.899912
# 2        Australia  2005.0     7.340688           10.658608        0.967892
# 3        Australia  2007.0     7.285391           10.702894        0.965276
# 4        Australia  2008.0     7.253757           10.718780        0.946635
# ..             ...     ...          ...                 ...             ...
# 587  United States  2016.0     6.803600           10.985777        0.896751
# 588  United States  2017.0     6.991759           11.001395        0.921003
# 589  United States  2018.0     6.882685           11.025024        0.903856
# 590  United States  2019.0     6.943701           11.043353        0.916691
# 591  United States  2020.0     7.028088           11.000656        0.937370
#
#      Freedom to make life choices  Perceptions of corruption LOCATION  \
# 0                        0.831966                   0.841052      ARG
# 1                        0.845895                   0.855255      ARG
# 2                        0.934973                   0.390416      AUS
# 3                        0.890682                   0.512578      AUS
# 4                        0.915733                   0.430811      AUS
# ..                            ...                        ...      ...
# 587                      0.757893                   0.738920      USA
# 588                      0.868497                   0.681191      USA
# 589                      0.824607                   0.709928      USA
# 590                      0.836139                   0.706716      USA
# 591                      0.850447                   0.678125      USA
#
#      Inflation rate  Adult education  Housing prices  Trust in government
# 0         24.795600        17.488495             NaN                  NaN
# 1         34.277230        31.336042             NaN                  NaN
# 2          9.712082        34.967968       56.664750                  NaN
# 3          1.405548        31.816732       66.960250                  NaN
# 4         12.489460        30.064018       69.602750                  NaN
# ..              ...              ...             ...                  ...
# 587       -6.584728         9.852750      105.637315            29.720566
# 588        7.916659         9.354493      112.170681            38.653502
# 589        7.529873         9.176164      119.143333            31.381609
# 590       -2.112950         9.189871      125.207117            36.277444
# 591       -8.520787         8.277081      135.045036            46.491709
#
# [592 rows x 12 columns]

# %%
# adult education
df_v6 = clean_data(df_v5, 'self-employment', 'Self-employment rate')

# %%
# poverty rates
df_v7 = clean_data(df_v6, 'poverty', 'Poverty rate')

# %%
# adult education
df_v8 = clean_data(df_v7, 'unemployed-youth', 'Unemployed youth rate')
df_v8 = df_v8.dropna(thresh=14).reset_index(drop=True)
df_v8
# Out:
#       Country name    TIME  Life Ladder  Log GDP per capita  Social support  \
# 0        Australia  2010.0     7.450047           10.722262        0.954520
# 1        Australia  2011.0     7.405616           10.732697        0.967029
# 2        Australia  2012.0     7.195586           10.753672        0.944599
# 3        Australia  2013.0     7.364169           10.761981        0.928205
# 4        Australia  2014.0     7.288550           10.772080        0.923799
# ..             ...     ...          ...                 ...             ...
# 411  United States  2016.0     6.803600           10.985777        0.896751
# 412  United States  2017.0     6.991759           11.001395        0.921003
# 413  United States  2018.0     6.882685           11.025024        0.903856
# 414  United States  2019.0     6.943701           11.043353        0.916691
# 415  United States  2020.0     7.028088           11.000656        0.937370
#
#      Freedom to make life choices  Perceptions of corruption LOCATION  \
# 0                        0.932059                   0.366127      AUS
# 1                        0.944586                   0.381772      AUS
# 2                        0.935146                   0.368252      AUS
# 3                        0.933379                   0.431539      AUS
# 4                        0.922932                   0.442021      AUS
# ..                            ...                        ...      ...
# 411                      0.757893                   0.738920      USA
# 412                      0.868497                   0.681191      USA
# 413                      0.824607                   0.709928      USA
# 414                      0.836139                   0.706716      USA
# 415                      0.850447                   0.678125      USA
#
#      Inflation rate  Adult education  Housing prices  Trust in government  \
# 0          8.548600        26.792744       80.877000            60.975292
# 1         10.980910        25.922543       79.134750            53.078672
# 2          7.324251        23.563389       78.880250            42.041918
# 3          6.317400        24.284430       84.106500            45.587147
# 4          1.184765        22.895836       91.720250            46.467623
# ..              ...              ...             ...                  ...
# 411       -6.584728         9.852750      105.637315            29.720566
# 412        7.916659         9.354493      112.170681            38.653502
# 413        7.529873         9.176164      119.143333            31.381609
# 414       -2.112950         9.189871      125.207117            36.277444
# 415       -8.520787         8.277081      135.045036            46.491709
#
#      Self-employment rate  Poverty rate  Unemployed youth rate
# 0               13.774050           NaN               8.059968
# 1               13.220600           NaN               7.839816
# 2               12.216890         0.129               7.231065
# 3               11.975450           NaN               7.336304
# 4               12.052440         0.130               7.217288
# ..                    ...           ...                    ...
# 411              7.466977         0.209               8.533521
# 412              7.109162         0.212               7.455460
# 413              7.262526         0.211               7.458875
# 414              6.994946         0.210               7.903465
# 415              7.046813           NaN               7.699012
#
# [416 rows x 15 columns]

# %%
print(f"""
{df_v8['Inflation rate'].isna().sum()}
{df_v8['Adult education'].isna().sum()}
{df_v8['Housing prices'].isna().sum()}
{df_v8['Trust in government'].isna().sum()}
{df_v8['Self-employment rate'].isna().sum()}
{df_v8['Poverty rate'].isna().sum()}
{df_v8['Unemployed youth rate'].isna().sum()}
""")
# Out:
# 7
# 0
# 0
# 37
# 36
# 97
# 14

# %%
df_v8.rename(columns={'TIME': 'Year', 'LOCATION': 'Country code'}, inplace=True)
df_v8
# Out:
#       Country name    Year  Life Ladder  Log GDP per capita  Social support  \
# 0        Australia  2010.0     7.450047           10.722262        0.954520
# 1        Australia  2011.0     7.405616           10.732697        0.967029
# 2        Australia  2012.0     7.195586           10.753672        0.944599
# 3        Australia  2013.0     7.364169           10.761981        0.928205
# 4        Australia  2014.0     7.288550           10.772080        0.923799
# ..             ...     ...          ...                 ...             ...
# 411  United States  2016.0     6.803600           10.985777        0.896751
# 412  United States  2017.0     6.991759           11.001395        0.921003
# 413  United States  2018.0     6.882685           11.025024        0.903856
# 414  United States  2019.0     6.943701           11.043353        0.916691
# 415  United States  2020.0     7.028088           11.000656        0.937370
#
#      Freedom to make life choices  Perceptions of corruption Country code  \
# 0                        0.932059                   0.366127          AUS
# 1                        0.944586                   0.381772          AUS
# 2                        0.935146                   0.368252          AUS
# 3                        0.933379                   0.431539          AUS
# 4                        0.922932                   0.442021          AUS
# ..                            ...                        ...          ...
# 411                      0.757893                   0.738920          USA
# 412                      0.868497                   0.681191          USA
# 413                      0.824607                   0.709928          USA
# 414                      0.836139                   0.706716          USA
# 415                      0.850447                   0.678125          USA
#
#      Inflation rate  Adult education  Housing prices  Trust in government  \
# 0          8.548600        26.792744       80.877000            60.975292
# 1         10.980910        25.922543       79.134750            53.078672
# 2          7.324251        23.563389       78.880250            42.041918
# 3          6.317400        24.284430       84.106500            45.587147
# 4          1.184765        22.895836       91.720250            46.467623
# ..              ...              ...             ...                  ...
# 411       -6.584728         9.852750      105.637315            29.720566
# 412        7.916659         9.354493      112.170681            38.653502
# 413        7.529873         9.176164      119.143333            31.381609
# 414       -2.112950         9.189871      125.207117            36.277444
# 415       -8.520787         8.277081      135.045036            46.491709
#
#      Self-employment rate  Poverty rate  Unemployed youth rate
# 0               13.774050           NaN               8.059968
# 1               13.220600           NaN               7.839816
# 2               12.216890         0.129               7.231065
# 3               11.975450           NaN               7.336304
# 4               12.052440         0.130               7.217288
# ..                    ...           ...                    ...
# 411              7.466977         0.209               8.533521
# 412              7.109162         0.212               7.455460
# 413              7.262526         0.211               7.458875
# 414              6.994946         0.210               7.903465
# 415              7.046813           NaN               7.699012
#
# [416 rows x 15 columns]

# %%
df_v8.to_csv('../cleaned_data/extended_happiness.csv', index=False)

# %% [markdown]
# relative povert
# GDP
# extend. by years(?)
# quality of life in eiuropean cities
